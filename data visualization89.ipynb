# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,10])
ypoints = np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5E5DA0510>]
# None

# %%
x = np.array([0,5])
y = np.array([0,25])
print(plt.plot(x,y,marker=#39;p&#39;))
print(plt.show())
# Out:
#   Cell In[3], line 4
#     print(plt.show())
#                      ^
# SyntaxError: incomplete input

# %%
x = np.array([0,5])
y = np.array([0,25])
print(plt.plot(x,y,marker='p'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5E667EAD0>]
# None

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5E6700BD0>]
# None

# %%
ypoints = np.array([5,7,1,0,3])
print(plt.plot(ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5E66B2ED0>]
# None

# %%
xpoints= np.array([3,8,1,4,9])
ypoints = np.array([5,7,1,0,3])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5E667AED0>]
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
#Title and label
ypoints = np.array([3, 8, 1, 10, 5, 7])
print(plt.plot(ypoints, linestyle='dashed'))
plt.title('Sample graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5E666AED0>]
# None

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])
print(plt.plot(ypoints, marker ='o'))
print(plt.show())

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

print(plt.plot(xpoints, ypoints,'violet'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5EC0AFC90>]
# None
# [<matplotlib.lines.Line2D object at 0x000001C5E671BE10>]
# None

# %%
print(plt.plot(xpoints, ypoints, linewidth='30', color='c'))
print(plt.show())


y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

print(plt.plot(y1))
print(plt.plot(y2))
plt.grid()
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001C5EC4A0BD0>]
# None
# [<matplotlib.lines.Line2D object at 0x000001C5EC4E4710>]
# [<matplotlib.lines.Line2D object at 0x000001C5EC036950>]
# None

# %%
#sub_plot
#plot 1
x = np.array([0,1,2,3,4,5])
y = np.array([3,8,1,10,9,4])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
#plot 2
x= np.array([1, 2, 6, 8])
y= np.array([3, 8, 1, 10])
plt.subplot(1,2,2)
plt.scatter(x, y)
plt.show()

# %%
#scatter 1
a=np.array([5, 7, 9,10])
b=np.array([2, 5, 8,2])

plt.scatter(a,b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([5, 7, 2, 15])

plt.bar(x,y)
plt.show()

# %%
plt.bar([0.5,2.5,4.5,6.5,8.5],[50,40,70,80,20],
label="BMW",width=1)
plt.bar([1.5,3.5,5.5,7.5,9.5], [80,20,20,50,60],
label="Audi",color='c', width=1)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance(kms)')
plt.title('Information')
plt.show()

# %%
#Horizontal bar
plt.barh(x,y)
plt.show()

# %%
#Color option
plt.bar(x,y, color='yellow')
plt.show()

# %%
#width option
plt.bar(x,y, color='g', width=0.1)
plt.show()

# %%
#Histogram
x = np.random.normal(300, 20, 250)
plt.hist(x)
plt.show()

# %%
#Pie chart
y = np.array([40, 30, 20, 10])
plt.pie(y)
plt.show()

# %%
#With Labels
y = np.array([35, 25, 25, 15])
mylabels = ["MPMC","PPML","ContolSystem","PSA"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
#Explode
y = np.array([35, 25, 25, 15])
mylabels = ["MPMC","PPML","ContolSystem","PSA"]

myexplode = [0, 0, 0.3, 0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as no
import plotly.express as px


Xpoints=np.array([0,20,120,200])
Ypoints=np.array([10,80,100,120,150,180,250])

# %%
Print(sns.scatterplot(data=ypoints))
Print(plt.show())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 Print(sns.scatterplot(data=ypoints))
#       2 Print(plt.show())
#
# NameError: name 'Print' is not defined

# %%
#3-D plot
X=np.array([1,2,6,8,12,14,20])
Y=np.array([3,8,1,10,12,16,18])
Fig=plt.figure(figsize=(12,8))
Ax=plt.axes(prohection='3d')
Plt_3d=ax.scatter3D(x,y)
Plt.colorbar(plt_3d)
Plt.show()
#plotly package
X=np.array([10,80,100,120,150,180,250])

fig=px.scatter(x)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 5
#       3 Y=np.array([3,8,1,10,12,16,18])
#       4 Fig=plt.figure(figsize=(12,8))
# ----> 5 Ax=plt.axes(prohection='3d')
#       6 Plt_3d=ax.scatter3D(x,y)
#       7 Plt.colorbar(plt_3d)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1122, in axes(arg, **kwargs)
#    1120 if arg is None:
#    1121     if pos is None:
# -> 1122         return fig.add_subplot(**kwargs)
#    1123     else:
#    1124         return fig.add_axes(pos, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# --> 757     ax = projection_class(self, *args, **pkw)
#     758     key = (projection_class, pkw)
#     759 return self._add_axes_internal(ax, key)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:697, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     694 if yscale:
#     695     self.set_yscale(yscale)
# --> 697 self._internal_update(kwargs)
#     699 for name, axis in self._axis_map.items():
#     700     axis.callbacks._connect_picklable(
#     701         'units', self._unit_change_handler(name))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Axes.set() got an unexpected keyword argument 'prohection'
